# %% [markdown]
# # Aula 14 - Exercícios de Estruturas Condicionais

# %% [markdown]
# #### 1 - Faça um programa que peça dois números e imprima o maior deles.

# %%
x = float(input('Insira o primeiro número: '))
y = float(input('Insira o segundo número: '))

print()
if x > y:
    print(f'O maior número é {x}')
elif x == y:
    print(f'Os números são iguais!')
else:
    print(f'O maior valor é {y}')
# Out:
# O maior número é 5.0

# %% [markdown]
# #### 2 - Faça um programa que verifique se uma letra digitada é vogal ou consoante.

# %%
x = input('Insira uma letra: ')
x = x.lower()

print()
if x == 'a' or x == 'e' or \
    x == 'i' or x == 'o' or x == 'u':
    print('A letra informada é uma vogal.')
else:
    print('A letra informada é uma consoante.')
# Out:
# A letra informada é uma vogal.

# %% [markdown]
# #### 3 - Faça um Programa que peça um número inteiro e determine se ele é par ou impar

# %%
x = int(input('Insira um número inteiro: '))
print()

if x % 2 == 0:
    print(f'{x} é par!')
else:
    print(f'{x} é ímpar!')
# Out:
# 5 é ímpar!

# %% [markdown]
# #### 4 - Construa um algoritmo que dado quatro valores (A, B, C e D), o algoritmo imprima o maior e o menor valor.

# %%
a = float(input('Valor de A: '))
b = float(input('Valor de B: '))
c = float(input('Valor de C: '))
d = float(input('Valor de D: '))

# Inicializando o maior e menor valor com o primeiro valor
maior = a
menor = a

# Verificando o maior valor
if b > maior:
    maior = b
if c > maior:
    maior = c
if d > maior:
    maior = d

# Verificando o menor valor
if b < menor:
    menor = b
if c < menor:
    menor = c
if d < menor:
    menor = d

print(f'O maior valor é {maior} e o menor é {menor}')
# Out:
# Valor de A: 1
# Valor de B: 2
# Valor de C: 3
# Valor de D: 4
# O maior valro é 4.0 e o menor é 1.0

# %%
# Outra forma mais simples4
lista = [a, b, c, d]
print(f'O maior valor é {max(lista)} e o menor é {min(lista)}.')
# Out:
# O maior valor é 4.0 e o menor é 1.0.

# %% [markdown]
# ##### 5 - Escreva um algoritmo que leia um número e informe se ele é divisível por 10, por 5 ou por 2 ou se não é divisível por nenhum deles.

# %%
x = int(input('Informe um número: '))
print()

if x % 10 == 0:
    print(f'{x} é divisível por 10, 5 e 2.')
elif x % 5 == 0 and x % 2 == 0:
    print(f'{x} é divisível apenas por 5 e 2.')
elif x % 5 == 0:
    print(f'{x} é divisível apenas por 5.')
elif x % 2 == 0:
    print(f'{x} é divisível apenas por 2.')
else:
    print(f'Não é divisível por nenhum deles.')
# Out:
# Não é divisível por nenhum deles.

# %% [markdown]
# #### 6 - Dada a string frase = "O dia está ensolarado e agradável", escreva um código em Python que verifique se a palavra "ensolarado" está presente na frase. Se a palavra estiver na frase, imprima "A palavra foi encontrada!", caso contrário, imprima "A palavra não foi encontrada."

# %%
frase = 'O dia está ensolarado e agradável, mas acho que amanhã vai chover'

if "ensolarado" in frase:
    print('A palavra foi encontrada!')
else:
    print('A palavra não foi encontrada')
# Out:
# A palavra foi encontrada!

# %% [markdown]
# #### 7 - Faça um programa que pergunte em que turno você estuda. Observação: utilize M, V e N para indicar matutino, vespertino ou noturno, respectivamente.". Imprima a mensagem "Bom Dia!", "Boa Tarde!" ou "Boa Noite!" ou "Valor Inválido!", conforme o caso.

# %%
print('Diga em qual turno você estuda.')
print('Obs: M, V e N para matutino, vespertino ou noturno, respectivamente.')
turno = input('Seu turno: ')
print()

turno = turno.lower()
if turno == 'm':
    print('Bom dia!')
elif turno == 't':
    print('Boa tarde!')
elif turno == 'n':
    print('Boa noite!')
else:
    print('Valor Inválido!')
# Out:
# Diga em qual turno você estuda.
# Obs: M, V e N para matutino, vespertino ou noturno, respectivamente.
#
# Boa noite!

# %% [markdown]
# #### 8 - Uma fruteira está vendendo frutas com os seguintes preços:
#
# Morango:
#
#         Até 5 Kg:        R$ 2,20 por Kg
#         Acima de 5 Kg:   R$ 2,50 por Kg
#
# Maçã:
#
#         Até 5 Kg:        R$ 1,80 por Kg
#         Acima de 5 Kg:   R$ 1,50 por Kg
#
#
#
# Se o cliente comprar mais de 8 Kg em frutas ou o valor total da compra ultrapassar R$ 25,00, receberá um desconto de 10% sobre este total. Escreva um algoritmo para ler a quantidade (em kg) de morangos e a quantidade (em kg) de maças adquiridas e escreva o valor a ser pago pelo cliente.

# %%
peso = float(input('Insira o peso total: '))
preço = float(input('Insira o preço total: '))

if peso > 8 or preço > 25:
    preço *= 0.9

print(f'Valor a ser pago: R$ {preço:.2f}')
# Out:
# Valor a ser pago: R$ 27.00

# %% [markdown]
# #### 9 - As Organizações Tabajara resolveram dar um aumento de salário aos seus colaboradores e lhe contraram para desenvolver o programa que calculará os reajustes.
#
#
# Faça um programa que recebe o salário de um colaborador em R$ e o reajuste segundo o seguinte critério, baseado no salário atual:
#
# - Salários até R$ 280,00 (incluindo) : aumento de 20%
#
# - Salários entre R$ 280,00 e R$ 700,00 : aumento de 15%
#
# - Salários entre R$ 700,00 e R$ 1500,00 : aumento de 10%
#
# - Salários de R$ 1500,00 em diante : aumento de 5%
#
# Após o aumento ser realizado, informe na tela:
#
# - O salário antes do reajuste;
# - O percentual de aumento aplicado;
# - O valor do aumento;
# - O novo salário, após o aumento.

# %%
salario = float(input('Informe o salário em R$ a ser reajustado: '))
print()
salario_antigo = salario
percentual = 0

if salario <= 280:
    salario *= 1.2
    percentual = 20
elif 280 < salario <= 700:
    salario *= 1.15
    percentual = 15
elif 700 < salario <= 1500:
    salario *= 1.1
    percentual = 10
else:
    salario *= 1.05
    percentual = 5

print(f'Salário antes do reajuste: R$ {salario_antigo}')
print(f'Percentual de aumento aplicado: {percentual}%')
print(f'Valor do aumento: R$ {salario_antigo*percentual/100:.2f}')
print(f'Novo salário: R$ {salario:.2f}')
# Out:
# Salário antes do reajuste: R$ 100.0
# Percentual de aumento aplicado: 20%
# Valor do aumento: R$ 20.00
# Novo salário: R$ 120.00

# %% [markdown]
# #### 10 - Faça um programa que faça 5 perguntas para uma pessoa sobre um crime. As perguntas são:
#
# "Telefonou para a vítima?"
#
# "Esteve no local do crime?"
#
# "Mora perto da vítima?"
#
# "Devia para a vítima?"
#
# "Já trabalhou com a vítima?"
#
#  O programa deve no final emitir uma classificação sobre a participação da pessoa no crime. Se a pessoa responder positivamente a 2 questões ela deve ser classificada como "Suspeita", entre 3 e 4 como "Cúmplice" e 5 como "Assassino". Caso contrário, ele será classificado como "Inocente".

# %%
print('Responda todas as perguntas com S para sim e N para não.')
p1 = input('Telefonou para a vítima? ').lower()
p2 = input('Esteve no local do crime? ').lower()
p3 = input('Mora perto da vítima? ').lower()
p4 = input('Devia para a vítima? ').lower()
p5 = input('Já trabalhou com a vítima? ').lower()

print()
lista = [p1, p2, p3, p4, p5]
contador = lista.count('s')
if contador < 2:
    print('Inocente.')
elif contador < 3:
    print('Suspeita.')
elif contador < 5:
    print('Cúmplice.')
else:
    print('Assasino.')
# Out:
# Responda todas as perguntas com S para sim e N para não.
#
# Assasino

# %% [markdown]
# # SIGA, CURTA E COMPARTILHE!
